# %%
import numpy as np
import math
import pandas as pd

# %% [markdown]
# Write a Python program to accept a string value from the user and display
# the count of each character in that string. Sample input: Enter a string
# value: assembly Sample output: a=1, s=2, e=1, m=1, b=1, l=1, y=1

# %%
from typing import Counter
n=input('enter a string')
for i in n:
  a=Counter(i)
  print(a)
# Out:
# enter a stringassemblyy
# Counter({'a': 1})
# Counter({'s': 1})
# Counter({'s': 1})
# Counter({'e': 1})
# Counter({'m': 1})
# Counter({'b': 1})
# Counter({'l': 1})
# Counter({'y': 1})
# Counter({'y': 1})

# %% [markdown]
#  Write a Python function to find the maximum of three numbers Sample
# input: 34,12,7 Sample output: 34

# %%
n=int(input('enter the first num '))
m=int(input('enter the seccond num '))
o=int(input('enter the third num '))
if((n>m)&(n>o)):
  print(n,' is greatest')
elif((m>n)&(m>o)):
  print(m,"is grestest")
else:
  print(o,'is greatest')
# Out:
# enter the first num 34
# enter the seccond num 24
# enter the third num 56
# 56 is greatest

# %% [markdown]
# Write a Python function called exponent(base,exp) that returns an
# integer value of base raises to the power of exp. Sample input: Enter the
# base: 2 Enter the exponent: 3 Sample output: 8

# %%
def exponent(base,exp):
  out=num**exp
  print(out)
num=int(input('enter the number'))
exp=int(input('enter the exponent'))
print(exponent(num,exp))
# Out:
# enter the number2
# enter the exponent3
# 8
# None

# %% [markdown]
# Write a Python function that takes a positive integer and returns the sum
# of the cube of all the positive integers smaller than the specified number.
# Sample input: 4 Sample output: 36.

# %%
def integer(n):
  sum=0
  for i in range(1,num):
    j=i**3
    sum=sum+j
  print(sum)
num=int(input('enter a number'))
print(integer(num))
# Out:
# enter a number4
# 36
# None

# %% [markdown]
# Write a Python program which iterates from 1 to 10. For multiples of 2,
# print “Fizz” instead of the number and for the multiples of 5, print “Buzz”.
# For numbers which are multiples of both 2 and 5, print “FizzBuzz”.
# Sample input: numbers from 1 to 10 Sample output: 1 Fizz 3 Fizz Buzz
# Fizz 7 Fizz 9 FizzBuzz

# %%
for i in range(1,11):
  if(((i%2==0)&(i%5==0))):
    print("fizzbuzz")
  elif(i%2==0):
    print("fizz")
  elif(i%5==0):
    print("buzz")
  else:
    print(i)
# Out:
# 1
# fizz
# 3
# fizz
# buzz
# fizz
# 7
# fizz
# 9
# fizzbuzz

# %% [markdown]
#  Write a Python program to find the most frequent item in a list of
# numbers. Sample input: 2, 3, 4, 2, 5, 2 Sample output: 2

# %%
num=int(input("enter the number of element"))
k=[]
for i in range(num):
  element=int(input('enter element'))
  k.append(element)
# Out:
# enter the number of element4
# enter element1
# enter element2
# enter element2
# enter element3
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# <ipython-input-50-70f3f1919deb> in <cell line: 7>()
#       5   element=int(input('enter element'))
#       6   k.append(element)
# ----> 7 print(statistics.mode([k]))
#
# /usr/lib/python3.10/statistics.py in mode(data)
#     577
#     578     """
# --> 579     pairs = Counter(iter(data)).most_common(1)
#     580     try:
#     581         return pairs[0][0]
#
# /usr/lib/python3.10/collections/__init__.py in __init__(self, iterable, **kwds)
#     575         '''
#     576         super().__init__()
# --> 577         self.update(iterable, **kwds)
#     578
#     579     def __missing__(self, key):
#
# /usr/lib/python3.10/collections/__init__.py in update(self, iterable, **kwds)
#     668                     super().update(iterable)
#     669             else:
# --> 670                 _count_elements(self, iterable)
#     671         if kwds:
#     672             self.update(kwds)
#
# TypeError: unhashable type: 'list'

# %% [markdown]
# Write a Python program to find the sum of squares of the numbers in a
# list. Sample input: 2,1,3,1 Sample output: 15

# %%
num=int(input("enter the number of element"))
k=[]
sum=0
for i in range(num):
  element=int(input('enter element'))
  k.append(element)
print(k)
for i in k:
  out=i**2
  sum=sum+out
print(sum)
# Out:
# enter the number of element4
# enter element2
# enter element1
# enter element3
# enter element1
# [2, 1, 3, 1]
# 15

# %% [markdown]
# . Write a Python program using for loop that will iterate from 1 to 15. For
# each iteration, check if the current number is odd or even, and display the
# message to the screen as odd or even. Sample input: 1….15 Sample
# output: 1-odd 2-even …. 15-odd

# %%
for i in range(1,16):
  if(i%2==0):
    print(i,'-even')
  else:
    print(i,"-odd")
# Out:
# 1 -odd
# 2 -even
# 3 -odd
# 4 -even
# 5 -odd
# 6 -even
# 7 -odd
# 8 -even
# 9 -odd
# 10 -even
# 11 -odd
# 12 -even
# 13 -odd
# 14 -even
# 15 -odd

# %% [markdown]
# Write a Python program to convert temperatures to and from Celsius
# Fahrenheit. [Formula: c/5=f-32/9 where c=temperature in Celsius and f=
# temperature in Fahrenheit.] Sample input: Temperature in Fahrenheit
# =41 Sample output: Temperature in Celsius =5

# %%
celc=(input('want to calculate  the celsius,type yes '))
celc=celc.upper()
if(celc=="YES"):
  fahr=int(input('enter the fahrenheit'))
  celcius=((fahr-32)*(5/9))
  print(celcius)
else:
  a=int(input('enter the celcuis'))
  fahren=(a*(9/5)+32)
  print(fahren)
# Out:
# want to calculate  the celsius,type yes no
# enter the celcuis32
# 89.6

# %% [markdown]
# Write a Python function to calculate the factorial of a number (a
# nonnegative integer). The function accepts the number as an argument.
# Sample input: 3 Sample output: 6

# %%
def fac(n):
  for i in range(1,n):
    g=i*(i+1)
  print(g)
j=int(input('enter the number'))
print(fac(j))
# Out:
# enter the number3
# 6
# None
